# %% [markdown]
# TVB Epileptor:
#
# $$
# \begin{eqnarray}
#                 \dot{x_{1}} &=& y_{1} - f_{1}(x_{1}, x_{2}) - z + I_{ext1} \\
#                 \dot{y_{1}} &=& c - d x_{1}^{2} - y_{1} \\
#                 \dot{z} &=&
#                 \begin{cases}
#                 r(4 (x_{1} - x_{0}) - z-0.1 z^{7}) & \text{if } x<0 \\
#                 r(4 (x_{1} - x_{0}) - z) & \text{if } x \geq 0
#                 \end{cases} \\
#                 \dot{x_{2}} &=& -y_{2} + x_{2} - x_{2}^{3} + I_{ext2} + 2 g - 0.3 (z-3.5) \\
#                 \dot{y_{2}} &=& 1 / \tau (-y_{2} + f_{2}(x_{2}))\\
#                 \dot{g} &=& -0.01 (g - 0.1 x_{1})
#   \end{eqnarray}
# $$
# where:
# $$
# \begin{eqnarray}
#                 f_{1}(x_{1}, x_{2}) &=&
#                 \begin{cases}
#                 a x_{1}^{3} - b x_{1}^2 & \text{if } x_{1} <0\\
#                 -(slope - x_{2} + 0.6(z-4)^2) x_{1} &\text{if }x_{1} \geq 0\\
#                 \end{cases}\\
#                 f_{2}(x_{2}) &=&
#                 \begin{cases}
#                 0 & \text{if } x_{2} <-0.25\\
#                 a_{2}(x_{2} + 0.25) & \text{if } x_{2} \geq -0.25
#                 \end{cases}
#   \end{eqnarray}
# $$

# %% [markdown]
# Episense Epileptor:
#
# $$
# \begin{eqnarray}
#                 \dot{x_{1}} &=& y_{1} - f_{1}(x_{1}, x_{2}) - z + I_{ext1} \\
#                 \dot{y_{1}} &=& c - d x_{1}^{2} - y_{1} \\
#                 \dot{z} &=&
#                 \begin{cases}
#                 r(4 (x_{1} - x_{0}) - z-0.1 z^{7}) & \text{if } x<0 \\
#                 r(4 (x_{1} - x_{0}) - z) & \text{if } x \geq 0
#                 \end{cases} \\
#                 \dot{x_{2}} &=& -y_{2} + x_{2} - x_{2}^{3} + I_{ext2} + 2 g - 0.3 (z-3.5) \\
#                 \dot{y_{2}} &=& 1 / \tau (-y_{2} + f_{2}(x_{2}))\\
#                 \dot{g} &=& -0.01 (g - 0.1 x_{1})
# \end{eqnarray}
# $$
# where:
# $$
# \begin{eqnarray}
#                 f_{1}(x_{1}, x_{2}) &=&
#                 \begin{cases}
#                 a x_{1}^{3} - b x_{1}^2 & \text{if } x_{1} <0\\
#                 -(slope - x_{2} + 0.6(z-4)^2) x_{1} &\text{if }x_{1} \geq 0\\
#                 \end{cases}\\
#                 f_{2}(x_{2}) &=&
#                 \begin{cases}
#                 0 & \text{if } x_{2} <-0.25\\
#                 a_{2}(x_{2} + 0.25) & \text{if } x_{2} \geq -0.25
#                 \end{cases}
# \end{eqnarray}
# $$

# %% [markdown]
# 2D Epileptor for LSA:
# $$
# \begin{eqnarray}
#                 \dot{x_{1}} &=& y_{1} - f(x_{1}, x_{2}) - z + I_{ext1} \\
#                 \dot{z} &=& r( 4 (x_{1} - x_{0}) - z )
# \end{eqnarray}
# $$
# where:
# $$
# \begin{eqnarray}
#                 f(x_{1}, z) &=&
#                 \begin{cases}
#                 a x_{1}^{3} + b x_{1}^2 & \text{if } x_{1} <0\\
#                 (b_{2} x_{1} - 0.6(z-4)^2 - slope) x_{1} &\text{if }x_{1} \geq 0\\
#                 \end{cases}\\
#   \end{eqnarray}
# $$

# %% [markdown]
# 2D Epileptor:
# $$
# \begin{eqnarray}
#                 \dot{x_{1}} &=& y_{1} - f(x_{1}, x_{2}) - z + I_{ext1} \\
#                 \dot{z} &=& r( x_{0} +3/(1+e^{(-x_{1}-0.5)/0.1})) - z )
# \end{eqnarray}
# $$
# where:
# $$
# \begin{eqnarray}
#                 f(x_{1}, z) &=&
#                 \begin{cases}
#                 a x_{1}^{3} + b x_{1}^2 & \text{if } x_{1} <0\\
#                 (b_{2} x_{1} - 0.6(z-4)^2 - slope) x_{1} &\text{if }x_{1} \geq 0\\
#                 \end{cases}\\
#   \end{eqnarray}
# $$

# %% [markdown]
# TVB Epileptor with DP x0 parameters:
#
# $$
# \begin{eqnarray}
#                 \dot{x_{1}} &=& y_{1} - f_{1}(x_{1}, x_{2}) - z + I_{ext1} \\
#                 \dot{y_{1}} &=& c - d x_{1}^{2} - y_{1} \\
#                 \dot{z} &=&
#                 \begin{cases}
#                 r(4 (x_{1} - x_{0} + 2.1) - z-0.1 z^{7}) & \text{if } x<0 \\
#                 r(4 (x_{1} - x_{0} + 2.1) - z) & \text{if } x \geq 0
#                 \end{cases} \\
#                 \dot{x_{2}} &=& -y_{2} + x_{2} - x_{2}^{3} + I_{ext2} + 2 g - 0.3 (z-3.5) \\
#                 \dot{y_{2}} &=& 1 / \tau (-y_{2} + f_{2}(x_{2}))\\
#                 \dot{g} &=& -0.01 (g - 0.1 x_{1})
#   \end{eqnarray}
# $$
# where:
# $$
# \begin{eqnarray}
#                 f_{1}(x_{1}, x_{2}) &=&
#                 \begin{cases}
#                 a x_{1}^{3} - b x_{1}^2 & \text{if } x_{1} <0\\
#                 -(slope - x_{2} + 0.6(z-4)^2) x_{1} &\text{if }x_{1} \geq 0\\
#                 \end{cases}\\
#                 f_{2}(x_{2}) &=&
#                 \begin{cases}
#                 0 & \text{if } x_{2} <-0.25\\
#                 a_{2}(x_{2} + 0.25) & \text{if } x_{2} \geq -0.25
#                 \end{cases}
#   \end{eqnarray}
# $$

# %% [markdown]
# Episense Epileptor with DP x0 parameters:
#
# $$
# \begin{eqnarray}
#                 \dot{x_{1}} &=& y_{1} - f_{1}(x_{1}, x_{2}) - z + I_{ext1} \\
#                 \dot{y_{1}} &=& c - d x_{1}^{2} - y_{1} \\
#                 \dot{z} &=&
#                 \begin{cases}
#                 r(4 (x_{1} - x_{0} + 2.91) - z-0.1 z^{7}) & \text{if } x<0 \\
#                 r(4 (x_{1} - x_{0} + 2.91) - z) & \text{if } x \geq 0
#                 \end{cases} \\
#                 \dot{x_{2}} &=& -y_{2} + x_{2} - x_{2}^{3} + I_{ext2} + 2 g - 0.3 (z-3.5) \\
#                 \dot{y_{2}} &=& 1 / \tau (-y_{2} + f_{2}(x_{2}))\\
#                 \dot{g} &=& -0.01 (g - 0.1 x_{1})
# \end{eqnarray}
# $$
# where:
# $$
# \begin{eqnarray}
#                 f_{1}(x_{1}, x_{2}) &=&
#                 \begin{cases}
#                 a x_{1}^{3} - b x_{1}^2 & \text{if } x_{1} <0\\
#                 -(slope - x_{2} + 0.6(z-4)^2) x_{1} &\text{if }x_{1} \geq 0\\
#                 \end{cases}\\
#                 f_{2}(x_{2}) &=&
#                 \begin{cases}
#                 0 & \text{if } x_{2} <-0.25\\
#                 a_{2}(x_{2} + 0.25) & \text{if } x_{2} \geq -0.25
#                 \end{cases}
# \end{eqnarray}
# $$

# %% [markdown]
# 2D Epileptor for LSA with DP x0 parameters:
# $$
# \begin{eqnarray}
#                 \dot{x_{1}} &=& y_{1} - f(x_{1}, x_{2}) - z + I_{ext1} \\
#                 \dot{z} &=& r( 4 (x_{1} - x_{0} + 2.1) - z )
# \end{eqnarray}
# $$
# where:
# $$
# \begin{eqnarray}
#                 f(x_{1}, z) &=&
#                 \begin{cases}
#                 a x_{1}^{3} + b x_{1}^2 & \text{if } x_{1} <0\\
#                 (b_{2} x_{1} - 0.6(z-4)^2 - slope) x_{1} &\text{if }x_{1} \geq 0\\
#                 \end{cases}\\
#   \end{eqnarray}
# $$

# %% [markdown]
# 2D Epileptor with DP x0 parameters:
# $$
# \begin{eqnarray}
#                 \dot{x_{1}} &=& y_{1} - f(x_{1}, x_{2}) - z + I_{ext1} \\
#                 \dot{z} &=& r( -x_{0} + 2.1 +3/(1+e^{(-x_{1}-0.5)/0.1})) - z )
# \end{eqnarray}
# $$
# where:
# $$
# \begin{eqnarray}
#                 f(x_{1}, z) &=&
#                 \begin{cases}
#                 a x_{1}^{3} + b x_{1}^2 & \text{if } x_{1} <0\\
#                 (b_{2} x_{1} - 0.6(z-4)^2 - slope) x_{1} &\text{if }x_{1} \geq 0\\
#                 \end{cases}\\
#   \end{eqnarray}
# $$
